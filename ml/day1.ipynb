# %% [markdown]
# ## the use and development of computer systems that are able to learn and adapt without following explicit instructions, by using algorithms and statistical models to analyse and draw inferences  from patterns in data.
# `

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/udit/Desktop/Data Science/datascience-learning/ml/day1.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/udit/Desktop/Data%20Science/datascience-learning/ml/day1.ipynb#ch0000001?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/home/udit/Desktop/Data%20Science/datascience-learning/ml/day1.ipynb#ch0000001?line=1'>2</a> df=pd.read_csv('titanic.csv')
#       <a href='vscode-notebook-cell:/home/udit/Desktop/Data%20Science/datascience-learning/ml/day1.ipynb#ch0000001?line=2'>3</a> df.head()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# # lets clean our data

# %%
da=df[['sex','age','fare','survived']]
da.head()
# Out:
#       sex    age      fare  survived
# 0  female  29.00  211.3375         1
# 1    male   0.92  151.5500         1
# 2  female   2.00  151.5500         0
# 3    male  30.00  151.5500         0
# 4  female  25.00  151.5500         0

# %%
da.describe()
# Out:
#                age         fare     survived
# count  1046.000000  1308.000000  1309.000000
# mean     29.881138    33.295479     0.381971
# std      14.413493    51.758668     0.486055
# min       0.170000     0.000000     0.000000
# 25%      21.000000     7.895800     0.000000
# 50%      28.000000    14.454200     0.000000
# 75%      39.000000    31.275000     1.000000
# max      80.000000   512.329200     1.000000

# %%
da.dropna()
# Out:
#          sex    age      fare  survived
# 0     female  29.00  211.3375         1
# 1       male   0.92  151.5500         1
# 2     female   2.00  151.5500         0
# 3       male  30.00  151.5500         0
# 4     female  25.00  151.5500         0
# ...      ...    ...       ...       ...
# 1301    male  45.50    7.2250         0
# 1304  female  14.50   14.4542         0
# 1306    male  26.50    7.2250         0
# 1307    male  27.00    7.2250         0
# 1308    male  29.00    7.8750         0
#
# [1045 rows x 4 columns]

# %%
X=da.drop(columns='survived')

# %%
y=da['survived']

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X,y)
model.predict(['male',17,157.5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 model=DecisionTreeClassifier()
# ----> 3 model.fit(X,y)
#       4 model.predict(['male',17,157.5])
#
# File ~/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py:898, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     861 def fit(self, X, y, sample_weight=None, check_input=True,
#     862         X_idx_sorted="deprecated"):
#     863     """Build a decision tree classifier from the training set (X, y).
#     864
#     865     Parameters
#    (...)
#     895         Fitted estimator.
#     896     """
# --> 898     super().fit(
#     899         X, y,
#     900         sample_weight=sample_weight,
#     901         check_input=check_input,
#     902         X_idx_sorted=X_idx_sorted)
#     903     return self
#
# File ~/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py:156, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156 X, y = self._validate_data(X, y,
#     157                            validate_separately=(check_X_params,
#     158                                                 check_y_params))
#     159 if issparse(X):
#     160     X.sort_indices()
#
# File ~/anaconda3/lib/python3.8/site-packages/sklearn/base.py:430, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     424 if validate_separately:
#     425     # We need this because some estimators validate X and y
#     426     # separately, and in general, separately calling check_array()
#     427     # on X and y isn't equivalent to just calling check_X_y()
#     428     # :(
#     429     check_X_params, check_y_params = validate_separately
# --> 430     X = check_array(X, **check_X_params)
#     431     y = check_array(y, **check_y_params)
#     432 else:
#
# File ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = ['{}={}'.format(name, arg)
#      67             for name, arg in zip(kwonly_args[:extra_args],
#      68                                  args[-extra_args:])]
#
# File ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:616, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614         array = array.astype(dtype, casting="unsafe", copy=False)
#     615     else:
# --> 616         array = np.asarray(array, order=order, dtype=dtype)
#     617 except ComplexWarning as complex_warning:
#     618     raise ValueError("Complex data not supported\n"
#     619                      "{}\n".format(array)) from complex_warning
#
# File ~/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102, in asarray(a, dtype, order, like)
#      99 if like is not None:
#     100     return _asarray_with_like(a, dtype=dtype, order=order, like=like)
# --> 102 return array(a, dtype, copy=False, order=order)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:1899, in NDFrame.__array__(self, dtype)
#    1898 def __array__(self, dtype=None) -> np.ndarray:
# -> 1899     return np.asarray(self._values, dtype=dtype)
#
# File ~/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102, in asarray(a, dtype, order, like)
#      99 if like is not None:
#     100     return _asarray_with_like(a, dtype=dtype, order=order, like=like)
# --> 102 return array(a, dtype, copy=False, order=order)
#
# ValueError: could not convert string to float: 'female'
