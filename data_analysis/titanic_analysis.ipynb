# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#loading a csv file

# %%
tit=pd.read_csv('titanic.csv')
tit
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# # TEST ON 100 ROWS OF DATA

# %%
t1=tit.head(100)
t1
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..     ...       ...                                                ...
# 95       1         1              Dodge, Mrs. Washington (Ruth Vidaver)
# 96       1         0                         Douglas, Mr. Walter Donald
# 97       1         1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 98       1         1        Douglas, Mrs. Walter Donald (Mahala Dutton)
# 99       1         1  Duff Gordon, Lady. (Lucille Christiana Sutherl...
#
#        sex    age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
t1.describe()
# Out:
#        pclass    survived        age      sibsp       parch        fare  \
# count   100.0  100.000000  91.000000  100.00000  100.000000  100.000000
# mean      1.0    0.670000  38.295824    0.45000    0.390000   91.988333
# std       0.0    0.472582  15.610169    0.55732    0.694786   88.657122
# min       1.0    0.000000   0.920000    0.00000    0.000000    0.000000
# 25%       1.0    0.000000  27.000000    0.00000    0.000000   30.500000
# 50%       1.0    1.000000  37.000000    0.00000    0.000000   65.237500
# 75%       1.0    1.000000  48.000000    1.00000    1.000000  120.000000
# max       1.0    1.000000  80.000000    2.00000    2.000000  512.329200
#
#              body
# count    8.000000
# mean   142.500000
# std     78.003663
# min     22.000000
# 25%    108.500000
# 50%    141.500000
# 75%    181.000000
# max    269.000000

# %%
t1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     100 non-null    int64
#  1   survived   100 non-null    int64
#  2   name       100 non-null    object
#  3   sex        100 non-null    object
#  4   age        91 non-null     float64
#  5   sibsp      100 non-null    int64
#  6   parch      100 non-null    int64
#  7   ticket     100 non-null    object
#  8   fare       100 non-null    float64
#  9   cabin      81 non-null     object
#  10  embarked   100 non-null    object
#  11  boat       68 non-null     object
#  12  body       8 non-null      float64
#  13  home.dest  90 non-null     object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 11.1+ KB

# %%
t1.sck()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 t1.atck()
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5465, in NDFrame.__getattr__(self, name)
#    5463 if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464     return self[name]
# -> 5465 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'atck'
